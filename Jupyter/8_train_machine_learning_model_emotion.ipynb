# %%
import numpy as np 
import pandas as pd
import pickle

# %% [markdown]
# # Data
# - Load data from pickle file
# - split the data into independent and dependent
# - split to train and test set

# %%
data = pickle.load(open('./data_face_features_emotion.pickle', mode='rb'))

# %%
x = np.array(data['data'])# indendepnd variable
y = np.array(data['label']) # dependt varibale

# %%
x.shape , y.shape
# Out:
# ((1413, 1, 128), (1413,))

# %%
x = x.reshape(-1,128)
x.shape
# Out:
# (1413, 128)

# %%
# split the data into train and test
from sklearn.model_selection import train_test_split

# %%
x_train,x_test, y_train,y_test = train_test_split(x,y,train_size=0.8,random_state=0)

# %%
x_train.shape, x_test.shape,y_train.shape, y_test.shape
# Out:
# ((1130, 128), (283, 128), (1130,), (283,))

# %% [markdown]
# # Train Machine Learing

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import VotingClassifier
from sklearn.metrics import classification_report, accuracy_score,f1_score

# %% [markdown]
# ### Logistic Regression

# %%
model_logistic = LogisticRegression()
model_logistic.fit(x_train,y_train) #training logistic Regression
# Out:
# LogisticRegression()

# %%
def get_report(model,x_train,y_train,x_test,y_test):
    y_pred_train = model.predict(x_train)
    y_pred_test = model.predict(x_test)

    # accuracy score
    acc_train = accuracy_score(y_train,y_pred_train)
    acc_test = accuracy_score(y_test,y_pred_test)

    # f1 score 
    f1_score_train = f1_score(y_train,y_pred_train,average='macro')
    f1_score_test = f1_score(y_test,y_pred_test,average='macro')
    
    print('Accuracy Train = %0.2f' %acc_train)
    print('Accuracy test = %0.2f' %acc_test)
    print('F1 Score Train = %0.2f' %f1_score_train)
    print('F1 Score Test = %0.2f' %f1_score_test)

# %%
get_report(model_logistic,x_train,y_train,x_test,y_test)
# Out:
# Accuracy Train = 0.31
# Accuracy test = 0.23
# F1 Score Train = 0.23
# F1 Score Test = 0.18

# %% [markdown]
# # Support Vector Machines

# %%
model_svc = SVC(probability=True)
model_svc.fit(x_train,y_train)
# Out:
# SVC(probability=True)

# %%
get_report(model_svc,x_train,y_train,x_test,y_test)
# Out:
# Accuracy Train = 0.42
# Accuracy test = 0.25
# F1 Score Train = 0.32
# F1 Score Test = 0.17

# %% [markdown]
# # Random Forest Classifier

# %%
model_rf = RandomForestClassifier(n_estimators=10)
model_rf.fit(x_train,y_train)
# Out:
# RandomForestClassifier(n_estimators=10)

# %%
get_report(model_rf,x_train,y_train,x_test,y_test)
# Out:
# Accuracy Train = 1.00
# Accuracy test = 0.45
# F1 Score Train = 0.99
# F1 Score Test = 0.46

# %% [markdown]
# # Voting Classifier

# %%
model_voting = VotingClassifier(estimators=[
    ('logistic',LogisticRegression()),
    ('svc',SVC(probability=True)),
    ('rf',RandomForestClassifier())
],voting='soft',weights=[1,2,3])

# %%
model_voting.fit(x_train,y_train)
# Out:
# VotingClassifier(estimators=[('logistic', LogisticRegression()),
#                              ('svc', SVC(probability=True)),
#                              ('rf', RandomForestClassifier())],
#                  voting='soft', weights=[1, 2, 3])

# %%
get_report(model_voting,x_train,y_train,x_test,y_test)
# Out:
# Accuracy Train = 1.00
# Accuracy test = 0.46
# F1 Score Train = 1.00
# F1 Score Test = 0.47

# %% [markdown]
# # Parameter Tuning

# %%
from sklearn.model_selection import GridSearchCV

# %%
model_grid = GridSearchCV(model_voting,
                          param_grid={
                              'svc__C':[3,5,7,10],
                              'svc__gamma':[0.1,0.3,0.5],
                              'rf__n_estimators':[5,10,20],
                              'rf__max_depth':[3,5,7],
                              'voting':['soft','hard']
                          },scoring='accuracy',cv=3,n_jobs=1,verbose=2)

# %%
model_grid.fit(x_train,y_train)
# Out:
# Fitting 3 folds for each of 108 candidates, totalling 324 fits
# [CV] END rf__max_depth=3, rf__n_estimators=5, svc__C=3, svc__gamma=0.1, voting=soft; total time=   0.2s
# [CV] END rf__max_depth=3, rf__n_estimators=5, svc__C=3, svc__gamma=0.1, voting=soft; total time=   0.2s
# [CV] END rf__max_depth=3, rf__n_estimators=5, svc__C=3, svc__gamma=0.1, voting=soft; total time=   0.2s
# [CV] END rf__max_depth=3, rf__n_estimators=5, svc__C=3, svc__gamma=0.3, voting=soft; total time=   0.2s
# [CV] END rf__max_depth=3, rf__n_estimators=5, svc__C=3, svc__gamma=0.3, voting=soft; total time=   0.2s
# [CV] END rf__max_depth=3, rf__n_estimators=5, svc__C=3, svc__gamma=0.3, voting=soft; total time=   0.2s
# [CV] END rf__max_depth=3, rf__n_estimators=5, svc__C=3, svc__gamma=0.5, voting=soft; total time=   0.2s
# [CV] END rf__max_depth=3, rf__n_estimators=5, svc__C=3, svc__gamma=0.5, voting=soft; total time=   0.2s
# [CV] END rf__max_depth=3, rf__n_estimators=5, svc__C=3, svc__gamma=0.5, voting=soft; total time=   0.2s
# [CV] END rf__max_depth=3, rf__n_estimators=5, svc__C=5, svc__gamma=0.1, voting=soft; total time=   0.2s
# [CV] END rf__max_depth=3, rf__n_estimators=5, svc__C=5, svc__gamma=0.1, voting=soft; total time=   0.2s
# [CV] END rf__max_depth=3, rf__n_estimators=5, svc__C=5, svc__gamma=0.1, voting=soft; total time=   0.2s
# [CV] END rf__max_depth=3, rf__n_estimators=5, svc__C=5, svc__gamma=0.3, voting=soft; total time=   0.2s
# [CV] END rf__max_depth=3, rf__n_estimators=5, svc__C=5, svc__gamma=0.3, voting=soft; total time=   0.2s
# [CV] END rf__max_depth=3, rf__n_estimators=5, svc__C=5, svc__gamma=0.3, voting=soft; total time=   0.2s
# [CV] END rf__max_depth=3, rf__n_estimators=5, svc__C=5, svc__gamma=0.5, voting=soft; total time=   0.2s
# [CV] END rf__max_depth=3, rf__n_estimators=5, svc__C=5, svc__gamma=0.5, voting=soft; total time=   0.2s
# [CV] END rf__max_depth=3, rf__n_estimators=5, svc__C=5, svc__gamma=0.5, voting=soft; total time=   0.2s
# [CV] END rf__max_depth=3, rf__n_estimators=5, svc__C=7, svc__gamma=0.1, voting=soft; total time=   0.2s
# [CV] END rf__max_depth=3, rf__n_estimators=5, svc__C=7, svc__gamma=0.1, voting=soft; total time=   0.2s
# [CV] END rf__max_depth=3, rf__n_estimators=5, svc__C=7, svc__gamma=0.1, voting=soft; total time=   0.2s
# [CV] END rf__max_depth=3, rf__n_estimators=5, svc__C=7, svc__gamma=0.3, voting=soft; total time=   0.2s
# [CV] END rf__max_depth=3, rf__n_estimators=5, svc__C=7, svc__gamma=0.3, voting=soft; total time=   0.2s
# [CV] END rf__max_depth=3, rf__n_estimators=5, svc__C=7, svc__gamma=0.3, voting=soft; total time=   0.2s
# [CV] END rf__max_depth=3, rf__n_estimators=5, svc__C=7, svc__gamma=0.5, voting=soft; total time=   0.3s
# [CV] END rf__max_depth=3, rf__n_estimators=5, svc__C=7, svc__gamma=0.5, voting=soft; total time=   0.3s
# [CV] END rf__max_depth=3, rf__n_estimators=5, svc__C=7, svc__gamma=0.5, voting=soft; total time=   0.2s
# [CV] END rf__max_depth=3, rf__n_estimators=5, svc__C=10, svc__gamma=0.1, voting=soft; total time=   0.2s
# [CV] END rf__max_depth=3, rf__n_estimators=5, svc__C=10, svc__gamma=0.1, voting=soft; total time=   0.2s
# [CV] END rf__max_depth=3, rf__n_estimators=5, svc__C=10, svc__gamma=0.1, voting=soft; total time=   0.2s
# [CV] END rf__max_depth=3, rf__n_estimators=5, svc__C=10, svc__gamma=0.3, voting=soft; total time=   0.2s
# [CV] END rf__max_depth=3, rf__n_estimators=5, svc__C=10, svc__gamma=0.3, voting=soft; total time=   0.3s
# [CV] END rf__max_depth=3, rf__n_estimators=5, svc__C=10, svc__gamma=0.3, voting=soft; total time=   0.2s
# [CV] END rf__max_depth=3, rf__n_estimators=5, svc__C=10, svc__gamma=0.5, voting=soft; total time=   0.3s
# [CV] END rf__max_depth=3, rf__n_estimators=5, svc__C=10, svc__gamma=0.5, voting=soft; total time=   0.3s
# [CV] END rf__max_depth=3, rf__n_estimators=5, svc__C=10, svc__gamma=0.5, voting=soft; total time=   0.2s
# [CV] END rf__max_depth=3, rf__n_estimators=10, svc__C=3, svc__gamma=0.1, voting=soft; total time=   0.3s
# [CV] END rf__max_depth=3, rf__n_estimators=10, svc__C=3, svc__gamma=0.1, voting=soft; total time=   0.3s
# [CV] END rf__max_depth=3, rf__n_estimators=10, svc__C=3, svc__gamma=0.1, voting=soft; total time=   0.2s
# [CV] END rf__max_depth=3, rf__n_estimators=10, svc__C=3, svc__gamma=0.3, voting=soft; total time=   0.3s
# [CV] END rf__max_depth=3, rf__n_estimators=10, svc__C=3, svc__gamma=0.3, voting=soft; total time=   0.3s
# [CV] END rf__max_depth=3, rf__n_estimators=10, svc__C=3, svc__gamma=0.3, voting=soft; total time=   0.2s
# [CV] END rf__max_depth=3, rf__n_estimators=10, svc__C=3, svc__gamma=0.5, voting=soft; total time=   0.3s
# [CV] END rf__max_depth=3, rf__n_estimators=10, svc__C=3, svc__gamma=0.5, voting=soft; total time=   0.2s
# [CV] END rf__max_depth=3, rf__n_estimators=10, svc__C=3, svc__gamma=0.5, voting=soft; total time=   0.3s
# [CV] END rf__max_depth=3, rf__n_estimators=10, svc__C=5, svc__gamma=0.1, voting=soft; total time=   0.2s
# [CV] END rf__max_depth=3, rf__n_estimators=10, svc__C=5, svc__gamma=0.1, voting=soft; total time=   0.2s
# [CV] END rf__max_depth=3, rf__n_estimators=10, svc__C=5, svc__gamma=0.1, voting=soft; total time=   0.3s
# [CV] END rf__max_depth=3, rf__n_estimators=10, svc__C=5, svc__gamma=0.3, voting=soft; total time=   0.2s
# [CV] END rf__max_depth=3, rf__n_estimators=10, svc__C=5, svc__gamma=0.3, voting=soft; total time=   0.2s
# [CV] END rf__max_depth=3, rf__n_estimators=10, svc__C=5, svc__gamma=0.3, voting=soft; total time=   0.2s
# [CV] END rf__max_depth=3, rf__n_estimators=10, svc__C=5, svc__gamma=0.5, voting=soft; total time=   0.2s
# [CV] END rf__max_depth=3, rf__n_estimators=10, svc__C=5, svc__gamma=0.5, voting=soft; total time=   0.3s
# [CV] END rf__max_depth=3, rf__n_estimators=10, svc__C=5, svc__gamma=0.5, voting=soft; total time=   0.3s
# [CV] END rf__max_depth=3, rf__n_estimators=10, svc__C=7, svc__gamma=0.1, voting=soft; total time=   0.2s
# [CV] END rf__max_depth=3, rf__n_estimators=10, svc__C=7, svc__gamma=0.1, voting=soft; total time=   0.3s
# [CV] END rf__max_depth=3, rf__n_estimators=10, svc__C=7, svc__gamma=0.1, voting=soft; total time=   0.2s
# [CV] END rf__max_depth=3, rf__n_estimators=10, svc__C=7, svc__gamma=0.3, voting=soft; total time=   0.3s
# [CV] END rf__max_depth=3, rf__n_estimators=10, svc__C=7, svc__gamma=0.3, voting=soft; total time=   0.3s
# [CV] END rf__max_depth=3, rf__n_estimators=10, svc__C=7, svc__gamma=0.3, voting=soft; total time=   0.3s
# [CV] END rf__max_depth=3, rf__n_estimators=10, svc__C=7, svc__gamma=0.5, voting=soft; total time=   0.3s
# [CV] END rf__max_depth=3, rf__n_estimators=10, svc__C=7, svc__gamma=0.5, voting=soft; total time=   0.3s
# [CV] END rf__max_depth=3, rf__n_estimators=10, svc__C=7, svc__gamma=0.5, voting=soft; total time=   0.3s
# [CV] END rf__max_depth=3, rf__n_estimators=10, svc__C=10, svc__gamma=0.1, voting=soft; total time=   0.2s
# [CV] END rf__max_depth=3, rf__n_estimators=10, svc__C=10, svc__gamma=0.1, voting=soft; total time=   0.2s
# [CV] END rf__max_depth=3, rf__n_estimators=10, svc__C=10, svc__gamma=0.1, voting=soft; total time=   0.2s
# [CV] END rf__max_depth=3, rf__n_estimators=10, svc__C=10, svc__gamma=0.3, voting=soft; total time=   0.3s
# [CV] END rf__max_depth=3, rf__n_estimators=10, svc__C=10, svc__gamma=0.3, voting=soft; total time=   0.2s
# [CV] END rf__max_depth=3, rf__n_estimators=10, svc__C=10, svc__gamma=0.3, voting=soft; total time=   0.3s
# [CV] END rf__max_depth=3, rf__n_estimators=10, svc__C=10, svc__gamma=0.5, voting=soft; total time=   0.3s
# [CV] END rf__max_depth=3, rf__n_estimators=10, svc__C=10, svc__gamma=0.5, voting=soft; total time=   0.3s
# [CV] END rf__max_depth=3, rf__n_estimators=10, svc__C=10, svc__gamma=0.5, voting=soft; total time=   0.3s
# [CV] END rf__max_depth=3, rf__n_estimators=20, svc__C=3, svc__gamma=0.1, voting=soft; total time=   0.3s
# [CV] END rf__max_depth=3, rf__n_estimators=20, svc__C=3, svc__gamma=0.1, voting=soft; total time=   0.3s
# [CV] END rf__max_depth=3, rf__n_estimators=20, svc__C=3, svc__gamma=0.1, voting=soft; total time=   0.3s
# [CV] END rf__max_depth=3, rf__n_estimators=20, svc__C=3, svc__gamma=0.3, voting=soft; total time=   0.3s
# [CV] END rf__max_depth=3, rf__n_estimators=20, svc__C=3, svc__gamma=0.3, voting=soft; total time=   0.3s
# [CV] END rf__max_depth=3, rf__n_estimators=20, svc__C=3, svc__gamma=0.3, voting=soft; total time=   0.3s
# [CV] END rf__max_depth=3, rf__n_estimators=20, svc__C=3, svc__gamma=0.5, voting=soft; total time=   0.3s
# [CV] END rf__max_depth=3, rf__n_estimators=20, svc__C=3, svc__gamma=0.5, voting=soft; total time=   0.3s
# [CV] END rf__max_depth=3, rf__n_estimators=20, svc__C=3, svc__gamma=0.5, voting=soft; total time=   0.3s
# [CV] END rf__max_depth=3, rf__n_estimators=20, svc__C=5, svc__gamma=0.1, voting=soft; total time=   0.3s
# [CV] END rf__max_depth=3, rf__n_estimators=20, svc__C=5, svc__gamma=0.1, voting=soft; total time=   0.3s
# [CV] END rf__max_depth=3, rf__n_estimators=20, svc__C=5, svc__gamma=0.1, voting=soft; total time=   0.3s
# [CV] END rf__max_depth=3, rf__n_estimators=20, svc__C=5, svc__gamma=0.3, voting=soft; total time=   0.3s
# [CV] END rf__max_depth=3, rf__n_estimators=20, svc__C=5, svc__gamma=0.3, voting=soft; total time=   0.3s
# [CV] END rf__max_depth=3, rf__n_estimators=20, svc__C=5, svc__gamma=0.3, voting=soft; total time=   0.3s
# [CV] END rf__max_depth=3, rf__n_estimators=20, svc__C=5, svc__gamma=0.5, voting=soft; total time=   0.3s
# [CV] END rf__max_depth=3, rf__n_estimators=20, svc__C=5, svc__gamma=0.5, voting=soft; total time=   0.3s
# [CV] END rf__max_depth=3, rf__n_estimators=20, svc__C=5, svc__gamma=0.5, voting=soft; total time=   0.3s
# [CV] END rf__max_depth=3, rf__n_estimators=20, svc__C=7, svc__gamma=0.1, voting=soft; total time=   0.3s
# [CV] END rf__max_depth=3, rf__n_estimators=20, svc__C=7, svc__gamma=0.1, voting=soft; total time=   0.3s
# [CV] END rf__max_depth=3, rf__n_estimators=20, svc__C=7, svc__gamma=0.1, voting=soft; total time=   0.2s
# [CV] END rf__max_depth=3, rf__n_estimators=20, svc__C=7, svc__gamma=0.3, voting=soft; total time=   0.3s
# [CV] END rf__max_depth=3, rf__n_estimators=20, svc__C=7, svc__gamma=0.3, voting=soft; total time=   0.3s
# [CV] END rf__max_depth=3, rf__n_estimators=20, svc__C=7, svc__gamma=0.3, voting=soft; total time=   0.3s
# [CV] END rf__max_depth=3, rf__n_estimators=20, svc__C=7, svc__gamma=0.5, voting=soft; total time=   0.3s
# [CV] END rf__max_depth=3, rf__n_estimators=20, svc__C=7, svc__gamma=0.5, voting=soft; total time=   0.3s
# [CV] END rf__max_depth=3, rf__n_estimators=20, svc__C=7, svc__gamma=0.5, voting=soft; total time=   0.3s
# [CV] END rf__max_depth=3, rf__n_estimators=20, svc__C=10, svc__gamma=0.1, voting=soft; total time=   0.2s
# [CV] END rf__max_depth=3, rf__n_estimators=20, svc__C=10, svc__gamma=0.1, voting=soft; total time=   0.3s
# [CV] END rf__max_depth=3, rf__n_estimators=20, svc__C=10, svc__gamma=0.1, voting=soft; total time=   0.3s
# [CV] END rf__max_depth=3, rf__n_estimators=20, svc__C=10, svc__gamma=0.3, voting=soft; total time=   0.3s
# [CV] END rf__max_depth=3, rf__n_estimators=20, svc__C=10, svc__gamma=0.3, voting=soft; total time=   0.3s
# [CV] END rf__max_depth=3, rf__n_estimators=20, svc__C=10, svc__gamma=0.3, voting=soft; total time=   0.3s
# [CV] END rf__max_depth=3, rf__n_estimators=20, svc__C=10, svc__gamma=0.5, voting=soft; total time=   0.3s
# [CV] END rf__max_depth=3, rf__n_estimators=20, svc__C=10, svc__gamma=0.5, voting=soft; total time=   0.3s
# [CV] END rf__max_depth=3, rf__n_estimators=20, svc__C=10, svc__gamma=0.5, voting=soft; total time=   0.3s
# [CV] END rf__max_depth=5, rf__n_estimators=5, svc__C=3, svc__gamma=0.1, voting=soft; total time=   0.3s
# [CV] END rf__max_depth=5, rf__n_estimators=5, svc__C=3, svc__gamma=0.1, voting=soft; total time=   0.2s
# [CV] END rf__max_depth=5, rf__n_estimators=5, svc__C=3, svc__gamma=0.1, voting=soft; total time=   0.2s
# [CV] END rf__max_depth=5, rf__n_estimators=5, svc__C=3, svc__gamma=0.3, voting=soft; total time=   0.2s
# [CV] END rf__max_depth=5, rf__n_estimators=5, svc__C=3, svc__gamma=0.3, voting=soft; total time=   0.2s
# [CV] END rf__max_depth=5, rf__n_estimators=5, svc__C=3, svc__gamma=0.3, voting=soft; total time=   0.2s
# [CV] END rf__max_depth=5, rf__n_estimators=5, svc__C=3, svc__gamma=0.5, voting=soft; total time=   0.2s
# [CV] END rf__max_depth=5, rf__n_estimators=5, svc__C=3, svc__gamma=0.5, voting=soft; total time=   0.2s
# [CV] END rf__max_depth=5, rf__n_estimators=5, svc__C=3, svc__gamma=0.5, voting=soft; total time=   0.2s
# [CV] END rf__max_depth=5, rf__n_estimators=5, svc__C=5, svc__gamma=0.1, voting=soft; total time=   0.2s
# [CV] END rf__max_depth=5, rf__n_estimators=5, svc__C=5, svc__gamma=0.1, voting=soft; total time=   0.2s
# [CV] END rf__max_depth=5, rf__n_estimators=5, svc__C=5, svc__gamma=0.1, voting=soft; total time=   0.2s
# [CV] END rf__max_depth=5, rf__n_estimators=5, svc__C=5, svc__gamma=0.3, voting=soft; total time=   0.2s
# [CV] END rf__max_depth=5, rf__n_estimators=5, svc__C=5, svc__gamma=0.3, voting=soft; total time=   0.2s
# [CV] END rf__max_depth=5, rf__n_estimators=5, svc__C=5, svc__gamma=0.3, voting=soft; total time=   0.2s
# [CV] END rf__max_depth=5, rf__n_estimators=5, svc__C=5, svc__gamma=0.5, voting=soft; total time=   0.2s
# [CV] END rf__max_depth=5, rf__n_estimators=5, svc__C=5, svc__gamma=0.5, voting=soft; total time=   0.3s
# [CV] END rf__max_depth=5, rf__n_estimators=5, svc__C=5, svc__gamma=0.5, voting=soft; total time=   0.2s
# [CV] END rf__max_depth=5, rf__n_estimators=5, svc__C=7, svc__gamma=0.1, voting=soft; total time=   0.2s
# [CV] END rf__max_depth=5, rf__n_estimators=5, svc__C=7, svc__gamma=0.1, voting=soft; total time=   0.2s
# [CV] END rf__max_depth=5, rf__n_estimators=5, svc__C=7, svc__gamma=0.1, voting=soft; total time=   0.3s
# [CV] END rf__max_depth=5, rf__n_estimators=5, svc__C=7, svc__gamma=0.3, voting=soft; total time=   0.3s
# [CV] END rf__max_depth=5, rf__n_estimators=5, svc__C=7, svc__gamma=0.3, voting=soft; total time=   0.3s
# [CV] END rf__max_depth=5, rf__n_estimators=5, svc__C=7, svc__gamma=0.3, voting=soft; total time=   0.3s
# [CV] END rf__max_depth=5, rf__n_estimators=5, svc__C=7, svc__gamma=0.5, voting=soft; total time=   0.3s
# [CV] END rf__max_depth=5, rf__n_estimators=5, svc__C=7, svc__gamma=0.5, voting=soft; total time=   0.3s
# [CV] END rf__max_depth=5, rf__n_estimators=5, svc__C=7, svc__gamma=0.5, voting=soft; total time=   0.3s
# [CV] END rf__max_depth=5, rf__n_estimators=5, svc__C=10, svc__gamma=0.1, voting=soft; total time=   0.3s
# [CV] END rf__max_depth=5, rf__n_estimators=5, svc__C=10, svc__gamma=0.1, voting=soft; total time=   0.3s
# [CV] END rf__max_depth=5, rf__n_estimators=5, svc__C=10, svc__gamma=0.1, voting=soft; total time=   0.3s
# [CV] END rf__max_depth=5, rf__n_estimators=5, svc__C=10, svc__gamma=0.3, voting=soft; total time=   0.3s
# [CV] END rf__max_depth=5, rf__n_estimators=5, svc__C=10, svc__gamma=0.3, voting=soft; total time=   0.4s
# [CV] END rf__max_depth=5, rf__n_estimators=5, svc__C=10, svc__gamma=0.3, voting=soft; total time=   0.3s
# [CV] END rf__max_depth=5, rf__n_estimators=5, svc__C=10, svc__gamma=0.5, voting=soft; total time=   0.3s
# [CV] END rf__max_depth=5, rf__n_estimators=5, svc__C=10, svc__gamma=0.5, voting=soft; total time=   0.3s
# [CV] END rf__max_depth=5, rf__n_estimators=5, svc__C=10, svc__gamma=0.5, voting=soft; total time=   0.3s
# [CV] END rf__max_depth=5, rf__n_estimators=10, svc__C=3, svc__gamma=0.1, voting=soft; total time=   0.3s
# [CV] END rf__max_depth=5, rf__n_estimators=10, svc__C=3, svc__gamma=0.1, voting=soft; total time=   0.3s
# [CV] END rf__max_depth=5, rf__n_estimators=10, svc__C=3, svc__gamma=0.1, voting=soft; total time=   0.2s
# [CV] END rf__max_depth=5, rf__n_estimators=10, svc__C=3, svc__gamma=0.3, voting=soft; total time=   0.2s
# [CV] END rf__max_depth=5, rf__n_estimators=10, svc__C=3, svc__gamma=0.3, voting=soft; total time=   0.2s
# [CV] END rf__max_depth=5, rf__n_estimators=10, svc__C=3, svc__gamma=0.3, voting=soft; total time=   0.2s
# [CV] END rf__max_depth=5, rf__n_estimators=10, svc__C=3, svc__gamma=0.5, voting=soft; total time=   0.2s
# [CV] END rf__max_depth=5, rf__n_estimators=10, svc__C=3, svc__gamma=0.5, voting=soft; total time=   0.2s
# [CV] END rf__max_depth=5, rf__n_estimators=10, svc__C=3, svc__gamma=0.5, voting=soft; total time=   0.2s
# [CV] END rf__max_depth=5, rf__n_estimators=10, svc__C=5, svc__gamma=0.1, voting=soft; total time=   0.2s
# [CV] END rf__max_depth=5, rf__n_estimators=10, svc__C=5, svc__gamma=0.1, voting=soft; total time=   0.2s
# [CV] END rf__max_depth=5, rf__n_estimators=10, svc__C=5, svc__gamma=0.1, voting=soft; total time=   0.2s
# [CV] END rf__max_depth=5, rf__n_estimators=10, svc__C=5, svc__gamma=0.3, voting=soft; total time=   0.2s
# [CV] END rf__max_depth=5, rf__n_estimators=10, svc__C=5, svc__gamma=0.3, voting=soft; total time=   0.3s
# [CV] END rf__max_depth=5, rf__n_estimators=10, svc__C=5, svc__gamma=0.3, voting=soft; total time=   0.3s
# [CV] END rf__max_depth=5, rf__n_estimators=10, svc__C=5, svc__gamma=0.5, voting=soft; total time=   0.3s
# [CV] END rf__max_depth=5, rf__n_estimators=10, svc__C=5, svc__gamma=0.5, voting=soft; total time=   0.3s
# [CV] END rf__max_depth=5, rf__n_estimators=10, svc__C=5, svc__gamma=0.5, voting=soft; total time=   0.2s
# [CV] END rf__max_depth=5, rf__n_estimators=10, svc__C=7, svc__gamma=0.1, voting=soft; total time=   0.3s
# [CV] END rf__max_depth=5, rf__n_estimators=10, svc__C=7, svc__gamma=0.1, voting=soft; total time=   0.3s
# [CV] END rf__max_depth=5, rf__n_estimators=10, svc__C=7, svc__gamma=0.1, voting=soft; total time=   0.3s
# [CV] END rf__max_depth=5, rf__n_estimators=10, svc__C=7, svc__gamma=0.3, voting=soft; total time=   0.3s
# [CV] END rf__max_depth=5, rf__n_estimators=10, svc__C=7, svc__gamma=0.3, voting=soft; total time=   0.3s
# [CV] END rf__max_depth=5, rf__n_estimators=10, svc__C=7, svc__gamma=0.3, voting=soft; total time=   0.3s
# [CV] END rf__max_depth=5, rf__n_estimators=10, svc__C=7, svc__gamma=0.5, voting=soft; total time=   0.3s
# [CV] END rf__max_depth=5, rf__n_estimators=10, svc__C=7, svc__gamma=0.5, voting=soft; total time=   0.3s
# [CV] END rf__max_depth=5, rf__n_estimators=10, svc__C=7, svc__gamma=0.5, voting=soft; total time=   0.2s
# [CV] END rf__max_depth=5, rf__n_estimators=10, svc__C=10, svc__gamma=0.1, voting=soft; total time=   0.3s
# [CV] END rf__max_depth=5, rf__n_estimators=10, svc__C=10, svc__gamma=0.1, voting=soft; total time=   0.2s
# [CV] END rf__max_depth=5, rf__n_estimators=10, svc__C=10, svc__gamma=0.1, voting=soft; total time=   0.3s
# [CV] END rf__max_depth=5, rf__n_estimators=10, svc__C=10, svc__gamma=0.3, voting=soft; total time=   0.2s
# [CV] END rf__max_depth=5, rf__n_estimators=10, svc__C=10, svc__gamma=0.3, voting=soft; total time=   0.3s
# [CV] END rf__max_depth=5, rf__n_estimators=10, svc__C=10, svc__gamma=0.3, voting=soft; total time=   0.3s
# [CV] END rf__max_depth=5, rf__n_estimators=10, svc__C=10, svc__gamma=0.5, voting=soft; total time=   0.3s
# [CV] END rf__max_depth=5, rf__n_estimators=10, svc__C=10, svc__gamma=0.5, voting=soft; total time=   0.3s
# [CV] END rf__max_depth=5, rf__n_estimators=10, svc__C=10, svc__gamma=0.5, voting=soft; total time=   0.3s
# [CV] END rf__max_depth=5, rf__n_estimators=20, svc__C=3, svc__gamma=0.1, voting=soft; total time=   0.3s
# [CV] END rf__max_depth=5, rf__n_estimators=20, svc__C=3, svc__gamma=0.1, voting=soft; total time=   0.3s
# [CV] END rf__max_depth=5, rf__n_estimators=20, svc__C=3, svc__gamma=0.1, voting=soft; total time=   0.3s
# [CV] END rf__max_depth=5, rf__n_estimators=20, svc__C=3, svc__gamma=0.3, voting=soft; total time=   0.3s
# [CV] END rf__max_depth=5, rf__n_estimators=20, svc__C=3, svc__gamma=0.3, voting=soft; total time=   0.3s
# [CV] END rf__max_depth=5, rf__n_estimators=20, svc__C=3, svc__gamma=0.3, voting=soft; total time=   0.3s
# [CV] END rf__max_depth=5, rf__n_estimators=20, svc__C=3, svc__gamma=0.5, voting=soft; total time=   0.3s
# [CV] END rf__max_depth=5, rf__n_estimators=20, svc__C=3, svc__gamma=0.5, voting=soft; total time=   0.3s
# [CV] END rf__max_depth=5, rf__n_estimators=20, svc__C=3, svc__gamma=0.5, voting=soft; total time=   0.3s
# [CV] END rf__max_depth=5, rf__n_estimators=20, svc__C=5, svc__gamma=0.1, voting=soft; total time=   0.3s
# [CV] END rf__max_depth=5, rf__n_estimators=20, svc__C=5, svc__gamma=0.1, voting=soft; total time=   0.3s
# [CV] END rf__max_depth=5, rf__n_estimators=20, svc__C=5, svc__gamma=0.1, voting=soft; total time=   0.3s
# [CV] END rf__max_depth=5, rf__n_estimators=20, svc__C=5, svc__gamma=0.3, voting=soft; total time=   0.3s
# [CV] END rf__max_depth=5, rf__n_estimators=20, svc__C=5, svc__gamma=0.3, voting=soft; total time=   0.3s
# [CV] END rf__max_depth=5, rf__n_estimators=20, svc__C=5, svc__gamma=0.3, voting=soft; total time=   0.3s
# [CV] END rf__max_depth=5, rf__n_estimators=20, svc__C=5, svc__gamma=0.5, voting=soft; total time=   0.3s
# [CV] END rf__max_depth=5, rf__n_estimators=20, svc__C=5, svc__gamma=0.5, voting=soft; total time=   0.3s
# [CV] END rf__max_depth=5, rf__n_estimators=20, svc__C=5, svc__gamma=0.5, voting=soft; total time=   0.3s
# [CV] END rf__max_depth=5, rf__n_estimators=20, svc__C=7, svc__gamma=0.1, voting=soft; total time=   0.3s
# [CV] END rf__max_depth=5, rf__n_estimators=20, svc__C=7, svc__gamma=0.1, voting=soft; total time=   0.3s
# [CV] END rf__max_depth=5, rf__n_estimators=20, svc__C=7, svc__gamma=0.1, voting=soft; total time=   0.3s
# [CV] END rf__max_depth=5, rf__n_estimators=20, svc__C=7, svc__gamma=0.3, voting=soft; total time=   0.3s
# [CV] END rf__max_depth=5, rf__n_estimators=20, svc__C=7, svc__gamma=0.3, voting=soft; total time=   0.3s
# [CV] END rf__max_depth=5, rf__n_estimators=20, svc__C=7, svc__gamma=0.3, voting=soft; total time=   0.3s
# [CV] END rf__max_depth=5, rf__n_estimators=20, svc__C=7, svc__gamma=0.5, voting=soft; total time=   0.3s
# [CV] END rf__max_depth=5, rf__n_estimators=20, svc__C=7, svc__gamma=0.5, voting=soft; total time=   0.3s
# [CV] END rf__max_depth=5, rf__n_estimators=20, svc__C=7, svc__gamma=0.5, voting=soft; total time=   0.3s
# [CV] END rf__max_depth=5, rf__n_estimators=20, svc__C=10, svc__gamma=0.1, voting=soft; total time=   0.3s
# [CV] END rf__max_depth=5, rf__n_estimators=20, svc__C=10, svc__gamma=0.1, voting=soft; total time=   0.3s
# [CV] END rf__max_depth=5, rf__n_estimators=20, svc__C=10, svc__gamma=0.1, voting=soft; total time=   0.3s
# [CV] END rf__max_depth=5, rf__n_estimators=20, svc__C=10, svc__gamma=0.3, voting=soft; total time=   0.3s
# [CV] END rf__max_depth=5, rf__n_estimators=20, svc__C=10, svc__gamma=0.3, voting=soft; total time=   0.3s
# [CV] END rf__max_depth=5, rf__n_estimators=20, svc__C=10, svc__gamma=0.3, voting=soft; total time=   0.3s
# [CV] END rf__max_depth=5, rf__n_estimators=20, svc__C=10, svc__gamma=0.5, voting=soft; total time=   0.3s
# [CV] END rf__max_depth=5, rf__n_estimators=20, svc__C=10, svc__gamma=0.5, voting=soft; total time=   0.3s
# [CV] END rf__max_depth=5, rf__n_estimators=20, svc__C=10, svc__gamma=0.5, voting=soft; total time=   0.3s
# [CV] END rf__max_depth=7, rf__n_estimators=5, svc__C=3, svc__gamma=0.1, voting=soft; total time=   0.2s
# [CV] END rf__max_depth=7, rf__n_estimators=5, svc__C=3, svc__gamma=0.1, voting=soft; total time=   0.2s
# [CV] END rf__max_depth=7, rf__n_estimators=5, svc__C=3, svc__gamma=0.1, voting=soft; total time=   0.2s
# [CV] END rf__max_depth=7, rf__n_estimators=5, svc__C=3, svc__gamma=0.3, voting=soft; total time=   0.3s
# [CV] END rf__max_depth=7, rf__n_estimators=5, svc__C=3, svc__gamma=0.3, voting=soft; total time=   0.2s
# [CV] END rf__max_depth=7, rf__n_estimators=5, svc__C=3, svc__gamma=0.3, voting=soft; total time=   0.2s
# [CV] END rf__max_depth=7, rf__n_estimators=5, svc__C=3, svc__gamma=0.5, voting=soft; total time=   0.2s
# [CV] END rf__max_depth=7, rf__n_estimators=5, svc__C=3, svc__gamma=0.5, voting=soft; total time=   0.2s
# [CV] END rf__max_depth=7, rf__n_estimators=5, svc__C=3, svc__gamma=0.5, voting=soft; total time=   0.2s
# [CV] END rf__max_depth=7, rf__n_estimators=5, svc__C=5, svc__gamma=0.1, voting=soft; total time=   0.2s
# [CV] END rf__max_depth=7, rf__n_estimators=5, svc__C=5, svc__gamma=0.1, voting=soft; total time=   0.2s
# [CV] END rf__max_depth=7, rf__n_estimators=5, svc__C=5, svc__gamma=0.1, voting=soft; total time=   0.2s
# [CV] END rf__max_depth=7, rf__n_estimators=5, svc__C=5, svc__gamma=0.3, voting=soft; total time=   0.2s
# [CV] END rf__max_depth=7, rf__n_estimators=5, svc__C=5, svc__gamma=0.3, voting=soft; total time=   0.2s
# [CV] END rf__max_depth=7, rf__n_estimators=5, svc__C=5, svc__gamma=0.3, voting=soft; total time=   0.2s
# [CV] END rf__max_depth=7, rf__n_estimators=5, svc__C=5, svc__gamma=0.5, voting=soft; total time=   0.2s
# [CV] END rf__max_depth=7, rf__n_estimators=5, svc__C=5, svc__gamma=0.5, voting=soft; total time=   0.3s
# [CV] END rf__max_depth=7, rf__n_estimators=5, svc__C=5, svc__gamma=0.5, voting=soft; total time=   0.2s
# [CV] END rf__max_depth=7, rf__n_estimators=5, svc__C=7, svc__gamma=0.1, voting=soft; total time=   0.2s
# [CV] END rf__max_depth=7, rf__n_estimators=5, svc__C=7, svc__gamma=0.1, voting=soft; total time=   0.2s
# [CV] END rf__max_depth=7, rf__n_estimators=5, svc__C=7, svc__gamma=0.1, voting=soft; total time=   0.2s
# [CV] END rf__max_depth=7, rf__n_estimators=5, svc__C=7, svc__gamma=0.3, voting=soft; total time=   0.2s
# [CV] END rf__max_depth=7, rf__n_estimators=5, svc__C=7, svc__gamma=0.3, voting=soft; total time=   0.3s
# [CV] END rf__max_depth=7, rf__n_estimators=5, svc__C=7, svc__gamma=0.3, voting=soft; total time=   0.2s
# [CV] END rf__max_depth=7, rf__n_estimators=5, svc__C=7, svc__gamma=0.5, voting=soft; total time=   0.3s
# [CV] END rf__max_depth=7, rf__n_estimators=5, svc__C=7, svc__gamma=0.5, voting=soft; total time=   0.3s
# [CV] END rf__max_depth=7, rf__n_estimators=5, svc__C=7, svc__gamma=0.5, voting=soft; total time=   0.2s
# [CV] END rf__max_depth=7, rf__n_estimators=5, svc__C=10, svc__gamma=0.1, voting=soft; total time=   0.2s
# [CV] END rf__max_depth=7, rf__n_estimators=5, svc__C=10, svc__gamma=0.1, voting=soft; total time=   0.2s
# [CV] END rf__max_depth=7, rf__n_estimators=5, svc__C=10, svc__gamma=0.1, voting=soft; total time=   0.2s
# [CV] END rf__max_depth=7, rf__n_estimators=5, svc__C=10, svc__gamma=0.3, voting=soft; total time=   0.2s
# [CV] END rf__max_depth=7, rf__n_estimators=5, svc__C=10, svc__gamma=0.3, voting=soft; total time=   0.3s
# [CV] END rf__max_depth=7, rf__n_estimators=5, svc__C=10, svc__gamma=0.3, voting=soft; total time=   0.2s
# [CV] END rf__max_depth=7, rf__n_estimators=5, svc__C=10, svc__gamma=0.5, voting=soft; total time=   0.2s
# [CV] END rf__max_depth=7, rf__n_estimators=5, svc__C=10, svc__gamma=0.5, voting=soft; total time=   0.2s
# [CV] END rf__max_depth=7, rf__n_estimators=5, svc__C=10, svc__gamma=0.5, voting=soft; total time=   0.3s
# [CV] END rf__max_depth=7, rf__n_estimators=10, svc__C=3, svc__gamma=0.1, voting=soft; total time=   0.3s
# [CV] END rf__max_depth=7, rf__n_estimators=10, svc__C=3, svc__gamma=0.1, voting=soft; total time=   0.3s
# [CV] END rf__max_depth=7, rf__n_estimators=10, svc__C=3, svc__gamma=0.1, voting=soft; total time=   0.3s
# [CV] END rf__max_depth=7, rf__n_estimators=10, svc__C=3, svc__gamma=0.3, voting=soft; total time=   0.3s
# [CV] END rf__max_depth=7, rf__n_estimators=10, svc__C=3, svc__gamma=0.3, voting=soft; total time=   0.3s
# [CV] END rf__max_depth=7, rf__n_estimators=10, svc__C=3, svc__gamma=0.3, voting=soft; total time=   0.3s
# [CV] END rf__max_depth=7, rf__n_estimators=10, svc__C=3, svc__gamma=0.5, voting=soft; total time=   0.3s
# [CV] END rf__max_depth=7, rf__n_estimators=10, svc__C=3, svc__gamma=0.5, voting=soft; total time=   0.3s
# [CV] END rf__max_depth=7, rf__n_estimators=10, svc__C=3, svc__gamma=0.5, voting=soft; total time=   0.2s
# [CV] END rf__max_depth=7, rf__n_estimators=10, svc__C=5, svc__gamma=0.1, voting=soft; total time=   0.2s
# [CV] END rf__max_depth=7, rf__n_estimators=10, svc__C=5, svc__gamma=0.1, voting=soft; total time=   0.2s
# [CV] END rf__max_depth=7, rf__n_estimators=10, svc__C=5, svc__gamma=0.1, voting=soft; total time=   0.3s
# [CV] END rf__max_depth=7, rf__n_estimators=10, svc__C=5, svc__gamma=0.3, voting=soft; total time=   0.2s
# [CV] END rf__max_depth=7, rf__n_estimators=10, svc__C=5, svc__gamma=0.3, voting=soft; total time=   0.3s
# [CV] END rf__max_depth=7, rf__n_estimators=10, svc__C=5, svc__gamma=0.3, voting=soft; total time=   0.3s
# [CV] END rf__max_depth=7, rf__n_estimators=10, svc__C=5, svc__gamma=0.5, voting=soft; total time=   0.3s
# [CV] END rf__max_depth=7, rf__n_estimators=10, svc__C=5, svc__gamma=0.5, voting=soft; total time=   0.3s
# [CV] END rf__max_depth=7, rf__n_estimators=10, svc__C=5, svc__gamma=0.5, voting=soft; total time=   0.3s
# [CV] END rf__max_depth=7, rf__n_estimators=10, svc__C=7, svc__gamma=0.1, voting=soft; total time=   0.3s
# [CV] END rf__max_depth=7, rf__n_estimators=10, svc__C=7, svc__gamma=0.1, voting=soft; total time=   0.3s
# [CV] END rf__max_depth=7, rf__n_estimators=10, svc__C=7, svc__gamma=0.1, voting=soft; total time=   0.3s
# [CV] END rf__max_depth=7, rf__n_estimators=10, svc__C=7, svc__gamma=0.3, voting=soft; total time=   0.3s
# [CV] END rf__max_depth=7, rf__n_estimators=10, svc__C=7, svc__gamma=0.3, voting=soft; total time=   0.3s
# [CV] END rf__max_depth=7, rf__n_estimators=10, svc__C=7, svc__gamma=0.3, voting=soft; total time=   0.3s
# [CV] END rf__max_depth=7, rf__n_estimators=10, svc__C=7, svc__gamma=0.5, voting=soft; total time=   0.3s
# [CV] END rf__max_depth=7, rf__n_estimators=10, svc__C=7, svc__gamma=0.5, voting=soft; total time=   0.3s
# [CV] END rf__max_depth=7, rf__n_estimators=10, svc__C=7, svc__gamma=0.5, voting=soft; total time=   0.3s
# [CV] END rf__max_depth=7, rf__n_estimators=10, svc__C=10, svc__gamma=0.1, voting=soft; total time=   0.3s
# [CV] END rf__max_depth=7, rf__n_estimators=10, svc__C=10, svc__gamma=0.1, voting=soft; total time=   0.3s
# [CV] END rf__max_depth=7, rf__n_estimators=10, svc__C=10, svc__gamma=0.1, voting=soft; total time=   0.3s
# [CV] END rf__max_depth=7, rf__n_estimators=10, svc__C=10, svc__gamma=0.3, voting=soft; total time=   0.3s
# [CV] END rf__max_depth=7, rf__n_estimators=10, svc__C=10, svc__gamma=0.3, voting=soft; total time=   0.3s
# [CV] END rf__max_depth=7, rf__n_estimators=10, svc__C=10, svc__gamma=0.3, voting=soft; total time=   0.3s
# [CV] END rf__max_depth=7, rf__n_estimators=10, svc__C=10, svc__gamma=0.5, voting=soft; total time=   0.3s
# [CV] END rf__max_depth=7, rf__n_estimators=10, svc__C=10, svc__gamma=0.5, voting=soft; total time=   0.3s
# [CV] END rf__max_depth=7, rf__n_estimators=10, svc__C=10, svc__gamma=0.5, voting=soft; total time=   0.3s
# [CV] END rf__max_depth=7, rf__n_estimators=20, svc__C=3, svc__gamma=0.1, voting=soft; total time=   0.3s
# [CV] END rf__max_depth=7, rf__n_estimators=20, svc__C=3, svc__gamma=0.1, voting=soft; total time=   0.4s
# [CV] END rf__max_depth=7, rf__n_estimators=20, svc__C=3, svc__gamma=0.1, voting=soft; total time=   0.3s
# [CV] END rf__max_depth=7, rf__n_estimators=20, svc__C=3, svc__gamma=0.3, voting=soft; total time=   0.3s
# [CV] END rf__max_depth=7, rf__n_estimators=20, svc__C=3, svc__gamma=0.3, voting=soft; total time=   0.3s
# [CV] END rf__max_depth=7, rf__n_estimators=20, svc__C=3, svc__gamma=0.3, voting=soft; total time=   0.3s
# [CV] END rf__max_depth=7, rf__n_estimators=20, svc__C=3, svc__gamma=0.5, voting=soft; total time=   0.3s
# [CV] END rf__max_depth=7, rf__n_estimators=20, svc__C=3, svc__gamma=0.5, voting=soft; total time=   0.4s
# [CV] END rf__max_depth=7, rf__n_estimators=20, svc__C=3, svc__gamma=0.5, voting=soft; total time=   0.3s
# [CV] END rf__max_depth=7, rf__n_estimators=20, svc__C=5, svc__gamma=0.1, voting=soft; total time=   0.3s
# [CV] END rf__max_depth=7, rf__n_estimators=20, svc__C=5, svc__gamma=0.1, voting=soft; total time=   0.4s
# [CV] END rf__max_depth=7, rf__n_estimators=20, svc__C=5, svc__gamma=0.1, voting=soft; total time=   0.3s
# [CV] END rf__max_depth=7, rf__n_estimators=20, svc__C=5, svc__gamma=0.3, voting=soft; total time=   0.3s
# [CV] END rf__max_depth=7, rf__n_estimators=20, svc__C=5, svc__gamma=0.3, voting=soft; total time=   0.3s
# [CV] END rf__max_depth=7, rf__n_estimators=20, svc__C=5, svc__gamma=0.3, voting=soft; total time=   0.3s
# [CV] END rf__max_depth=7, rf__n_estimators=20, svc__C=5, svc__gamma=0.5, voting=soft; total time=   0.3s
# [CV] END rf__max_depth=7, rf__n_estimators=20, svc__C=5, svc__gamma=0.5, voting=soft; total time=   0.4s
# [CV] END rf__max_depth=7, rf__n_estimators=20, svc__C=5, svc__gamma=0.5, voting=soft; total time=   0.3s
# [CV] END rf__max_depth=7, rf__n_estimators=20, svc__C=7, svc__gamma=0.1, voting=soft; total time=   0.3s
# [CV] END rf__max_depth=7, rf__n_estimators=20, svc__C=7, svc__gamma=0.1, voting=soft; total time=   0.3s
# [CV] END rf__max_depth=7, rf__n_estimators=20, svc__C=7, svc__gamma=0.1, voting=soft; total time=   0.3s
# [CV] END rf__max_depth=7, rf__n_estimators=20, svc__C=7, svc__gamma=0.3, voting=soft; total time=   0.3s
# [CV] END rf__max_depth=7, rf__n_estimators=20, svc__C=7, svc__gamma=0.3, voting=soft; total time=   0.3s
# [CV] END rf__max_depth=7, rf__n_estimators=20, svc__C=7, svc__gamma=0.3, voting=soft; total time=   0.3s
# [CV] END rf__max_depth=7, rf__n_estimators=20, svc__C=7, svc__gamma=0.5, voting=soft; total time=   0.3s
# [CV] END rf__max_depth=7, rf__n_estimators=20, svc__C=7, svc__gamma=0.5, voting=soft; total time=   0.3s
# [CV] END rf__max_depth=7, rf__n_estimators=20, svc__C=7, svc__gamma=0.5, voting=soft; total time=   0.3s
# [CV] END rf__max_depth=7, rf__n_estimators=20, svc__C=10, svc__gamma=0.1, voting=soft; total time=   0.3s
# [CV] END rf__max_depth=7, rf__n_estimators=20, svc__C=10, svc__gamma=0.1, voting=soft; total time=   0.3s
# [CV] END rf__max_depth=7, rf__n_estimators=20, svc__C=10, svc__gamma=0.1, voting=soft; total time=   0.3s
# [CV] END rf__max_depth=7, rf__n_estimators=20, svc__C=10, svc__gamma=0.3, voting=soft; total time=   0.3s
# [CV] END rf__max_depth=7, rf__n_estimators=20, svc__C=10, svc__gamma=0.3, voting=soft; total time=   0.3s
# [CV] END rf__max_depth=7, rf__n_estimators=20, svc__C=10, svc__gamma=0.3, voting=soft; total time=   0.3s
# [CV] END rf__max_depth=7, rf__n_estimators=20, svc__C=10, svc__gamma=0.5, voting=soft; total time=   0.3s
# [CV] END rf__max_depth=7, rf__n_estimators=20, svc__C=10, svc__gamma=0.5, voting=soft; total time=   0.3s
# [CV] END rf__max_depth=7, rf__n_estimators=20, svc__C=10, svc__gamma=0.5, voting=soft; total time=   0.3s
# GridSearchCV(cv=3,
#              estimator=VotingClassifier(estimators=[('logistic',
#                                                      LogisticRegression()),
#                                                     ('svc',
#                                                      SVC(probability=True)),
#                                                     ('rf',
#                                                      RandomForestClassifier())],
#                                         voting='soft', weights=[1, 2, 3]),
#              n_jobs=1,
#              param_grid={'rf__max_depth': [3, 5, 7],
#                          'rf__n_estimators': [5, 10, 20],
#                          'svc__C': [3, 5, 7, 10], 'svc__gamma': [0.1, 0.3, 0.5],
#                          'voting': ['soft']},
#              scoring='accuracy', verbose=2)

# %%
model_best_estimator = model_grid.best_estimator_

# %%
model_grid.best_score_
# Out:
# 0.34690633406700905

# %% [markdown]
# # Save Model

# %%
pickle.dump(model_best_estimator,open('../models/machinelearning_face_emotion_identity.pkl',mode='wb'))
